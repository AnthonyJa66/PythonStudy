# %% [markdown]
# # 二叉树用双链表形式表达

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %% [markdown]
# # 二叉树用列表形式表达——完全二叉树排布
#
# ![image.png](attachment:68493cdb-da71-4069-b80a-ea2c053214d2.png)

# %% [markdown]
# tree=[1,2,3,4,None,5]
#
# 二叉树的前序：根左右
#
# 二叉树的中序：左根右
#
# 二叉树的后序：左右根
# ![image.png](attachment:2e9efae3-1158-4e8d-9ad4-35e09419ac68.png)
